# %% [markdown]
# <a href="https://colab.research.google.com/github/adenafil/ust_ADE/blob/main/Copy_of_IF_UTS_Analisis_Data_Eksploratif_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # KESEPAKATAN BERSAMA
#
#
# > Bersama dengan ini saya berjanji akan melaksanakan ujian dengan jujur, tidak akan melakukan tindakan kecurangan apapun dalam berbagai bentuk. Saya berjanji akan mengerjakan soal ujian secara mandiri dan jujur, tidak akan membuka browser selain Google Colab dan Google Classroom. Saya berjanji tidak akan meminta ataupun memberikan jawaban dari soal ujian. Jika saya melakukan tindakan kecurangan selama ujian berlangsung, saya siap menerima konsekuensi sesuai dengan aturan akademik di UISI.

# %% [markdown]
# # Petunjuk Pengerjaan

# %% [markdown]
# **1. Terlebih dahulu, silakan salin notebook ini ke Google Drive anda dengan:**
#
#
# Klik File-Save a copy in Drive

# %% [markdown]
# **2. Tuliskan biodata anda (KLIK 2X)**
#
# > NAMA:Ade Nafil Firmansah
#
# > NIM:3012210002

# %% [markdown]
# **3. Lengkapi Notebook ini sesuai dengan petunjuk yang ada pada masing-masing bagian.**
#
# Setelah selesai, kumpulkan notebook anda dengan cara:
# 1. Simpan notebook (File -> Save), share ke email puji.andayani@uisi.ac.id
# 2. Download notebook (File -> UTS_NamaAnda.ipynb) dan copy link
# 3. Upload file dan link google colab di Classroom
# 4. Turn in di Classroom

# %% [markdown]
# **4. WAKTU UTS**
#
# > WAKTU PENGERJAAN: 08.00-09.50
#
# > BATAS UPLOAD CLASSROOM: 10.00

# %% [markdown]
# **5. SIFAT UJIAN**
#
# > BUKA E-BOOK Analisis Data Eksploratif, GOOGLE COLAB DAN GOOGLE CLASSROOM

# %% [markdown]
# # Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 1. Buatlah data frame seperti gambar berikut. Kemudian tampilkan (print) data frame nya.
#
# ![UTS_1.png](data:image/png;base64,...)

# %%
data = pd.DataFrame({'Nama': ['Dadang', 'Gea'], 'Kelas': ['A', 'B'], 'Keahlian': ['Software Engineering', np.nan]})
data
# Out:
#      Nama Kelas              Keahlian
# 0  Dadang     A  Software Engineering
# 1     Gea     B                   NaN

# %% [markdown]
# 2. Baca data berikut dan buatlah menjadi suatu 'DataFrame' dengan library 'pandas' dan simpan dengan nama variabel tertentu
#
# Download data pada url [http://data.bandung.go.id/index.php/portal/download/resource/b5b9ea92-d82b-4f1c-880d-8462d4077aeb])

# %%
csv = pd.read_csv('https://raw.githubusercontent.com/adenafil/ust_ADE/main/tahun-2021---data-rata-rata-suhu-dan-curah-hujan-menurut-bulan-di-kota-bandung.csv')
csv
# Out:
#     No      Bulan  Temperatur Rata-rata (oC)  Temperatur Maksimal (oC)  \
# 0    1    Januari                      23.32                     28.40
# 1    2   Februari                      23.48                     28.21
# 2    3      Maret                      23.65                     29.72
# 3    4      April                      23.74                     29.61
# 4    5        Mei                      24.09                     29.76
# 5    6       Juni                      23.49                     28.81
# 6    7       Juli                      23.14                     29.83
# 7    8    Agustus                      23.48                     29.61
# 8    9  September                      23.84                     30.17
# 9   10    Oktober                      23.95                     29.85
# 10  11   November                      23.43                     28.84
# 11  12   Desember                      23.73                     29.37
#
#     Temperatur Minimal (oC)  Jumlah Curah Hujan (mm)
# 0                     20.59                    148.6
# 1                     20.80                    153.9
# 2                     20.56                    309.0
# 3                     20.17                    177.2
# 4                     20.31                    238.9
# 5                     20.16                     92.4
# 6                     18.55                     33.2
# 7                     19.17                     91.8
# 8                     20.00                     73.0
# 9                     20.25                    218.4
# 10                    20.49                    454.3
# 11                    20.63                    198.5

# %% [markdown]
# 3. Tampilkan 8 data awal dari DataFrame tersebut

# %%
pd.options.display.max_rows = 8

csv = pd.read_csv('https://raw.githubusercontent.com/adenafil/ust_ADE/main/tahun-2021---data-rata-rata-suhu-dan-curah-hujan-menurut-bulan-di-kota-bandung.csv')
csv
# Out:
#     No      Bulan  Temperatur Rata-rata (oC)  Temperatur Maksimal (oC)  \
# 0    1    Januari                      23.32                     28.40
# 1    2   Februari                      23.48                     28.21
# 2    3      Maret                      23.65                     29.72
# 3    4      April                      23.74                     29.61
# ..  ..        ...                        ...                       ...
# 8    9  September                      23.84                     30.17
# 9   10    Oktober                      23.95                     29.85
# 10  11   November                      23.43                     28.84
# 11  12   Desember                      23.73                     29.37
#
#     Temperatur Minimal (oC)  Jumlah Curah Hujan (mm)
# 0                     20.59                    148.6
# 1                     20.80                    153.9
# 2                     20.56                    309.0
# 3                     20.17                    177.2
# ..                      ...                      ...
# 8                     20.00                     73.0
# 9                     20.25                    218.4
# 10                    20.49                    454.3
# 11                    20.63                    198.5
#
# [12 rows x 6 columns]

# %% [markdown]
# # Eksplorasi Data
#
# Menggunakan data frame pada soal nomor 2

# %% [markdown]
# 4. Berapa jumlah baris dari DataFrame, tampilkan jumlah barisnya.

# %%
jumlahBaris = len(csv.axes[0])
jumlahBaris
# Out:
# 12

# %% [markdown]
# 5. Berapa jumlah kolom dari DataFrame, tampilkan jumlah kolomnya.

# %%
jumlahColumn = len(csv.axes[1])
jumlahColumn
# Out:
# 6

# %% [markdown]
# 6. Tunjukkan data pada kolom 'Jumlah Curah Hujan (mm)'

# %%
pd.options.display.max_rows = 999
csv['Jumlah Curah Hujan (mm)']
# Out:
# 0     148.6
# 1     153.9
# 2     309.0
# 3     177.2
# 4     238.9
# 5      92.4
# 6      33.2
# 7      91.8
# 8      73.0
# 9     218.4
# 10    454.3
# 11    198.5
# Name: Jumlah Curah Hujan (mm), dtype: float64

# %% [markdown]
# 7. Tampilkan seluruh data pada bulan oktober (baris ke tiga terakhir)

# %%
tes = csv.iloc[9]
tes
# Out:
# No                                10
# Bulan                        Oktober
# Temperatur Rata-rata (oC)      23.95
# Temperatur Maksimal (oC)       29.85
# Temperatur Minimal (oC)        20.25
# Jumlah Curah Hujan (mm)        218.4
# Name: 9, dtype: object

# %% [markdown]
# # Statistika Deskriptif
#
# > Gunakan DataFrame pada https://cdn.uisi.ac.id/covid_2020-12-01.csv untuk menjawab pertanyaan berikut. Buat dataframe nya terlebih dahulu.

# %% [markdown]
# 8. Tampilkan nilai rata-rata dari jumlah kasus yang dirawat untuk semua provinsi

# %%
#dataframe
covid = pd.read_csv('https://raw.githubusercontent.com/adenafil/ust_ADE/main/covid_2020-12-01.csv')
covid
# Out:
#                       provinsi  lokasi_lintang  lokasi_bujur  jumlah_kasus  \
# 0                         ACEH        4.225615     96.910522          8301
# 1                         BALI       -8.369472    115.131714         13988
# 2                       BANTEN       -6.456736    106.109004         13215
# 3                     BENGKULU       -3.533584    102.338421          1842
# 4   DAERAH ISTIMEWA YOGYAKARTA       -7.894502    110.444878          6073
# 5                  DKI JAKARTA       -6.204699    106.836118        137919
# 6                    GORONTALO        0.687003    122.376058          3110
# 7                        JAMBI       -1.697698    102.723640          1993
# 8                   JAWA BARAT       -6.920432    107.603708         53395
# 9                  JAWA TENGAH       -7.259097    110.201115         56626
# 10                  JAWA TIMUR       -7.723346    112.732941         62313
# 11            KALIMANTAN BARAT       -0.086475    111.121178          2438
# 12          KALIMANTAN SELATAN       -2.993595    115.438578         13281
# 13           KALIMANTAN TENGAH       -1.602485    113.417654          6122
# 14            KALIMANTAN TIMUR        0.453858    116.468440         19748
# 15            KALIMANTAN UTARA        2.891013    116.218879          1523
# 16   KEPULAUAN BANGKA BELITUNG       -2.447444    106.549932          1036
# 17              KEPULAUAN RIAU        3.916346    108.261746          5490
# 18                     LAMPUNG       -4.916793    105.021437          3939
# 19                      MALUKU       -3.192572    129.576792          4620
# 20                MALUKU UTARA        0.212037    127.539107          2376
# 21         NUSA TENGGARA BARAT       -8.606999    117.508626          4697
# 22         NUSA TENGGARA TIMUR       -8.682205    121.592271          1242
# 23                       PAPUA       -4.666210    138.696030         10094
# 24                 PAPUA BARAT       -2.045160    132.976262          5352
# 25                        RIAU        0.511648    101.805109         20238
# 26              SULAWESI BARAT       -2.461746    119.345019          1473
# 27            SULAWESI SELATAN       -3.731081    120.162056         20804
# 28             SULAWESI TENGAH       -1.004137    121.201093          1872
# 29           SULAWESI TENGGARA       -4.124689    122.070311          6594
# 30              SULAWESI UTARA        1.259638    124.521240          6962
# 31              SUMATERA BARAT       -0.850253    100.465062         20098
# 32            SUMATERA SELATAN       -3.216212    104.169465          9530
# 33              SUMATERA UTARA        2.191894     99.051964         15671
#
#     jumlah_sembuh  jumlah_meninggal  jumlah_dirawat  laki_laki  perempuan  \
# 0            6631               329            1341       4052       4231
# 1           12466               428            1094       7218       6765
# 2            8830               334            4051       6470       6730
# 3            1427                77             338        778        986
# 4            4471               147            1455       2762       3308
# 5          125008              2683           10228      69088      66593
# 6            2970                90              50       1528       1580
# 7            1384                37             572        665        603
# 8           44509               922            7964      26912      25410
# 9           40369              2368           13889      17346      19436
# 10          54863              4438            3012      30024      32118
# 11           2055                22             361       1331       1094
# 12          11794               532             955       6839       6241
# 13           4681               194            1247       3101       2928
# 14          16384               561            2803      11691       7665
# 15            995                18             510        932        591
# 16            876                14             146        608        427
# 17           4189               138            1163       2829       2645
# 18           2025               135            1779       1920       2019
# 19           3797                61             762       2173       2354
# 20           1981                81             314       1235        929
# 21           3739               242             716       2297       2397
# 22            725                19             498        746        489
# 23           5030               140            4924       4441       3831
# 24           4578                88             686       2894       2446
# 25          17823               459            1956      10480       9741
# 26           1297                21             155        670        803
# 27          18603               497            1704       9925      10734
# 28           1126                72             674        920        900
# 29           5117               108            1369       3359       3222
# 30           5413               245            1304       3373       3479
# 31          15904               396            3798       9041      10355
# 32           7677               511            1342       4769       4569
# 33          13029               617            2025       7361       7994
#
#     usia_0_5  usia_6_18  usia_19_30  usia_31_45  usia_46_59  usia_60_keatas
# 0        180        444        1927        2938        1967             827
# 1        276        869        3569        3818        3541            1831
# 2        331       1234        3065        4097        3315            1080
# 3         35        152         410         613         399             213
# 4        182        849        1477        1358        1315             636
# 5       3600       9931       33950       40993       29429           14283
# 6         56        159        1113        1065         522             153
# 7         56        281         491         596         364             154
# 8       1785       6487       12655       15456       11107            4381
# 9       1656       5497       11761       15187       14735            7569
# 10      1012       4306       12338       17354       17795            8818
# 11        59        195         597         709         586             242
# 12       385       1234        3273        4000        2980            1074
# 13       193        641        1606        1879        1331             403
# 14       415       1349        4702        6172        3807            1269
# 15        29        122         447         529         302              90
# 16        35        166         229         325         191              74
# 17       165        520        1621        1765        1019             308
# 18        90        302         796        1145         920             403
# 19        65        388        1278        1604         920             259
# 20        37        116         689         767         392             136
# 21       120        333        1293        1480         919             538
# 22        21        105         501         302         190              76
# 23       250        757        2768        3399        1945             471
# 24       168        479        1713        1850         833             251
# 25       712       2343        5052        6408        4146            1443
# 26        18        541         347         304         179              82
# 27       470       1476        5350        6206        3720            1563
# 28        29         98         418         421         279             124
# 29        98        474        2117        2279        1165             412
# 30       120        462        1755        2170        1622             754
# 31       556       2133        4764        5570        4323            1998
# 32       347        749        2083        2713        2058            1197
# 33       284       1160        3655        4787        3608            1684

# %%
#mean
jumlahKasusRataRata = covid['jumlah_kasus'].mean()
jumlahKasusRataRata
# Out:
# 15999.264705882353

# %% [markdown]
# 9. Tampilkan nilai tengah (median) jumlah kasus untuk usia 6-18 tahun yang terkena covid-19 untuk semua provinsi

# %%
#median
medianCovid = covid['usia_6_18'].mean()
medianCovid
# Out:
# 1363.2941176470588

# %% [markdown]
# 10. Tampilkan jumlah total dari kasus sembuh untuk semua provinsi

# %%
provinsi = covid.iloc[:,0]
totalSembuhTiapProvinsi = covid.iloc[:,4]

gabung = pd.concat([provinsi, totalSembuhTiapProvinsi], axis = 1)
gabung
# Out:
#                       provinsi  jumlah_sembuh
# 0                         ACEH           6631
# 1                         BALI          12466
# 2                       BANTEN           8830
# 3                     BENGKULU           1427
# 4   DAERAH ISTIMEWA YOGYAKARTA           4471
# 5                  DKI JAKARTA         125008
# 6                    GORONTALO           2970
# 7                        JAMBI           1384
# 8                   JAWA BARAT          44509
# 9                  JAWA TENGAH          40369
# 10                  JAWA TIMUR          54863
# 11            KALIMANTAN BARAT           2055
# 12          KALIMANTAN SELATAN          11794
# 13           KALIMANTAN TENGAH           4681
# 14            KALIMANTAN TIMUR          16384
# 15            KALIMANTAN UTARA            995
# 16   KEPULAUAN BANGKA BELITUNG            876
# 17              KEPULAUAN RIAU           4189
# 18                     LAMPUNG           2025
# 19                      MALUKU           3797
# 20                MALUKU UTARA           1981
# 21         NUSA TENGGARA BARAT           3739
# 22         NUSA TENGGARA TIMUR            725
# 23                       PAPUA           5030
# 24                 PAPUA BARAT           4578
# 25                        RIAU          17823
# 26              SULAWESI BARAT           1297
# 27            SULAWESI SELATAN          18603
# 28             SULAWESI TENGAH           1126
# 29           SULAWESI TENGGARA           5117
# 30              SULAWESI UTARA           5413
# 31              SUMATERA BARAT          15904
# 32            SUMATERA SELATAN           7677
# 33              SUMATERA UTARA          13029

# %% [markdown]
# 11. Tampilkan nilai minimum dari jumlah kasus yang sembuh

# %%
minSembuh = gabung['jumlah_sembuh'].min()
minSembuh
# Out:
# 725

# %% [markdown]
# 12. Tampilkan nilai maksimum dari jumlah kasus yang sembuh

# %%
maxSembuh = gabung['jumlah_sembuh'].max()
maxSembuh
# Out:
# 125008

# %% [markdown]
# 13. Tampilkan nilai rata-rata jumlah kasus yang dirawat untuk semua provinsi yang lebih besar dari 5.000

# %%
meanSembuh = gabung['jumlah_sembuh'].mean()
meanSembuh
# Out:
# 13287.235294117647

# %% [markdown]
# 14. Tampilkan total jumlah kasus untuk usia 60 tahun ke atas untuk provinsi dengan kasus lebih dari 500

# %%
provinsi = covid.iloc[:,0]
jumlahKasus = covid.iloc[:,3]
tua = covid.iloc[:,14]


kondisi = pd.concat([provinsi, jumlahKasus, tua], axis = 1)

lebihDari500 = kondisi.loc[kondisi['jumlah_kasus'] >= 500]
lebihDari500
# Out:
#                       provinsi  jumlah_kasus  usia_60_keatas
# 0                         ACEH          8301             827
# 1                         BALI         13988            1831
# 2                       BANTEN         13215            1080
# 3                     BENGKULU          1842             213
# 4   DAERAH ISTIMEWA YOGYAKARTA          6073             636
# 5                  DKI JAKARTA        137919           14283
# 6                    GORONTALO          3110             153
# 7                        JAMBI          1993             154
# 8                   JAWA BARAT         53395            4381
# 9                  JAWA TENGAH         56626            7569
# 10                  JAWA TIMUR         62313            8818
# 11            KALIMANTAN BARAT          2438             242
# 12          KALIMANTAN SELATAN         13281            1074
# 13           KALIMANTAN TENGAH          6122             403
# 14            KALIMANTAN TIMUR         19748            1269
# 15            KALIMANTAN UTARA          1523              90
# 16   KEPULAUAN BANGKA BELITUNG          1036              74
# 17              KEPULAUAN RIAU          5490             308
# 18                     LAMPUNG          3939             403
# 19                      MALUKU          4620             259
# 20                MALUKU UTARA          2376             136
# 21         NUSA TENGGARA BARAT          4697             538
# 22         NUSA TENGGARA TIMUR          1242              76
# 23                       PAPUA         10094             471
# 24                 PAPUA BARAT          5352             251
# 25                        RIAU         20238            1443
# 26              SULAWESI BARAT          1473              82
# 27            SULAWESI SELATAN         20804            1563
# 28             SULAWESI TENGAH          1872             124
# 29           SULAWESI TENGGARA          6594             412
# 30              SULAWESI UTARA          6962             754
# 31              SUMATERA BARAT         20098            1998
# 32            SUMATERA SELATAN          9530            1197
# 33              SUMATERA UTARA         15671            1684

# %% [markdown]
# # Teknik Visualisasi Data

# %% [markdown]
# Buatlah minimal 5 visualisasi dari **data iklim pada soal nomor 2**.
#
# Berikan penjelasan untuk masing-masing visualisasi yang anda buat.
#
# Anda bisa menambahkan Code dan Text cell sesuai kebutuhan

# %% [markdown]
# Data pada url [http://data.bandung.go.id/index.php/portal/download/resource/b5b9ea92-d82b-4f1c-880d-8462d4077aeb])

# %% [markdown]
# 15. Penjelasan visualisasi 1

# %%
tolongVisual = pd.read_csv('https://raw.githubusercontent.com/adenafil/ust_ADE/main/tahun-2021---data-rata-rata-suhu-dan-curah-hujan-menurut-bulan-di-kota-bandung.csv')


tolongVisual
# Out:
#     No      Bulan  Temperatur Rata-rata (oC)  Temperatur Maksimal (oC)  \
# 0    1    Januari                      23.32                     28.40
# 1    2   Februari                      23.48                     28.21
# 2    3      Maret                      23.65                     29.72
# 3    4      April                      23.74                     29.61
# 4    5        Mei                      24.09                     29.76
# 5    6       Juni                      23.49                     28.81
# 6    7       Juli                      23.14                     29.83
# 7    8    Agustus                      23.48                     29.61
# 8    9  September                      23.84                     30.17
# 9   10    Oktober                      23.95                     29.85
# 10  11   November                      23.43                     28.84
# 11  12   Desember                      23.73                     29.37
#
#     Temperatur Minimal (oC)  Jumlah Curah Hujan (mm)
# 0                     20.59                    148.6
# 1                     20.80                    153.9
# 2                     20.56                    309.0
# 3                     20.17                    177.2
# 4                     20.31                    238.9
# 5                     20.16                     92.4
# 6                     18.55                     33.2
# 7                     19.17                     91.8
# 8                     20.00                     73.0
# 9                     20.25                    218.4
# 10                    20.49                    454.3
# 11                    20.63                    198.5

# %%
# kode visualisasi 1
tolongVisual = pd.read_csv('https://raw.githubusercontent.com/adenafil/ust_ADE/main/tahun-2021---data-rata-rata-suhu-dan-curah-hujan-menurut-bulan-di-kota-bandung.csv')


tolongVisual
# Out:
#     No      Bulan  Temperatur Rata-rata (oC)  Temperatur Maksimal (oC)  \
# 0    1    Januari                      23.32                     28.40
# 1    2   Februari                      23.48                     28.21
# 2    3      Maret                      23.65                     29.72
# 3    4      April                      23.74                     29.61
# 4    5        Mei                      24.09                     29.76
# 5    6       Juni                      23.49                     28.81
# 6    7       Juli                      23.14                     29.83
# 7    8    Agustus                      23.48                     29.61
# 8    9  September                      23.84                     30.17
# 9   10    Oktober                      23.95                     29.85
# 10  11   November                      23.43                     28.84
# 11  12   Desember                      23.73                     29.37
#
#     Temperatur Minimal (oC)  Jumlah Curah Hujan (mm)
# 0                     20.59                    148.6
# 1                     20.80                    153.9
# 2                     20.56                    309.0
# 3                     20.17                    177.2
# 4                     20.31                    238.9
# 5                     20.16                     92.4
# 6                     18.55                     33.2
# 7                     19.17                     91.8
# 8                     20.00                     73.0
# 9                     20.25                    218.4
# 10                    20.49                    454.3
# 11                    20.63                    198.5

# %%
plt.scatter(x=tolongVisual['Temperatur Rata-rata (oC)'], y=tolongVisual['Jumlah Curah Hujan (mm)'])

# %% [markdown]
# 16. Penjelasan visualisasi 2

# %%
# kode visualisasi 2
tolongVisual['Temperatur Rata-rata (oC)'].value_counts().plot(kind='pie', figsize=(6,6))
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# 17. Penjelasan visualisasi 3

# %%
# kode visualisasi 3
ax = tolongVisual['Temperatur Rata-rata (oC)'].value_counts().plot(kind='bar', figsize=(14,6))

# %% [markdown]
# 18. Penjelasan visualisasi 4

# %%
# kode visualisasi 4
sns.distplot(tolongVisual['Temperatur Rata-rata (oC)'], bins=10, kde=True )
# Out:
# <ipython-input-91-a03e07136570>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tolongVisual['Temperatur Rata-rata (oC)'], bins=10, kde=True )
# <Axes: xlabel='Temperatur Rata-rata (oC)', ylabel='Density'>

# %% [markdown]
# 19. Penjelasan visualisasi 5

# %%
# kode visualisasi 5
plt.plot(tolongVisual['Bulan'], tolongVisual['Temperatur Rata-rata (oC)'])
plt.grid()

# %% [markdown]
# 20. Buatlah sebuah visualisasi yang menggambarkan tingkat rata-rata temperatur dengan temperatur maksimalnya dalam setiap bulan seperti pada gambar berikut.
#
#
# ![UTS_2.png](data:image/png;base64,...)

# %%
# Visualisasi persebaran Temperatur
plt.plot(tolongVisual['Temperatur Rata-rata (oC)'], tolongVisual['Temperatur Minimal (oC)'])
plt.grid()

# %% [markdown]
# # Transformasi Data
#
# > Gunakan data frame pada soal nomor 2.

# %% [markdown]
# 21. Tambahkan satu kolom baru dengan nama `selisih temperatur`.
# Selisih temperatur dapat dihitung = temperatur maksimal dikurangi temperatur minimal.

# %%
wow = pd.read_csv('https://raw.githubusercontent.com/adenafil/ust_ADE/main/tahun-2021---data-rata-rata-suhu-dan-curah-hujan-menurut-bulan-di-kota-bandung.csv')
wow.insert(6, 'Selfish Temperature', tes['Temperatur Maksimal (oC)'] - tes['Temperatur Minimal (oC)'])


wow
# Out:
#     No      Bulan  Temperatur Rata-rata (oC)  Temperatur Maksimal (oC)  \
# 0    1    Januari                      23.32                     28.40
# 1    2   Februari                      23.48                     28.21
# 2    3      Maret                      23.65                     29.72
# 3    4      April                      23.74                     29.61
# 4    5        Mei                      24.09                     29.76
# 5    6       Juni                      23.49                     28.81
# 6    7       Juli                      23.14                     29.83
# 7    8    Agustus                      23.48                     29.61
# 8    9  September                      23.84                     30.17
# 9   10    Oktober                      23.95                     29.85
# 10  11   November                      23.43                     28.84
# 11  12   Desember                      23.73                     29.37
#
#     Temperatur Minimal (oC)  Jumlah Curah Hujan (mm)  Selfish Temperature
# 0                     20.59                    148.6                 7.81
# 1                     20.80                    153.9                 7.41
# 2                     20.56                    309.0                 9.16
# 3                     20.17                    177.2                 9.44
# 4                     20.31                    238.9                 9.45
# 5                     20.16                     92.4                 8.65
# 6                     18.55                     33.2                11.28
# 7                     19.17                     91.8                10.44
# 8                     20.00                     73.0                10.17
# 9                     20.25                    218.4                 9.60
# 10                    20.49                    454.3                 8.35
# 11                    20.63                    198.5                 8.74

# %% [markdown]
# 22. Dari hasil data frame baru yang terbentuk, dapatkan uotlier pada kolom 'Selisih Temperatur' yang di atas 12.

# %%
wow.describe()[['Selfish Temperature']]
# Out:
#        Selfish Temperature
# count            12.000000
# mean              9.208333
# std               1.106122
# min               7.410000
# 25%               8.575000
# 50%               9.300000
# 75%               9.742500
# max              11.280000
